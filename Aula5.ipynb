# %% [markdown]
# <a href="https://colab.research.google.com/github/joaomeira20/PA2026/blob/main/Aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Escrever um programa que converte a temperatura de C para F
#  F=(C * 9/5) + 32
# #Entrada
#
#  Temperatura de Celsius
#
#
# #Procesamento
#
#  Converter Celsius para fahrenheit
#
#
# #Saida
#
#
#  Mostrar a temperatura em Fahrenheit

# %%
# Calcular a area de um retangulo

comprimento = float (input("DIgite o valor de comprimento: "))
altura = float (input("Digite o falor da altura:  "))

 #Processamento

 area = ( * altura)

 #Saida

 print (f"a area do retangulo e igual : {area}")
# Out:
#   File "/tmp/ipykernel_334/3106367802.py", line 8
#     area = (comprimento * altura)
#     ^
# IndentationError: unexpected indent

# %%
#Cadastro de usuario simples

#Entrada

nome = str (input("digite o seu nome: "))
idade = int (input("digite sua idade: "))
altura = float (input("digite sua altura: "))
solteiro = True


#Saida
print (f" ola {nome}")
print (f" você tem {idade} anos e {altura} metros de altura")
print (f" Solteiro {solteiro}")
# Out:
# digite o seu nome: joao
# digite sua idade: 14
# digite sua altura: 1.49
#  ola joao
#  você tem 14 anos e 1.49 metros de altura
#  Solteiro True

# %%
#Entrada
Celsius = float (input(" Digite a trmperatura em Celsius: "))

#Processamento
Fahrenheit = (Celsius * (9/5) + 32)

#Saida
print (f" Em Fahrenheit {Fahrenheit}")
# Out:
#  Digite a trmperatura em Celsius: 14
#  Em Fahrenheit 57.2

# %% [markdown]
# # Operador esaritmedico
# + soma
#
# - subtracao
#
# * multiplicacao
#
# / divisao
#
# // dvisao inteira
#
# % resto da divisao
#
# ** potencia
#
# # Operadores relacionais
#
# == igual
#
# != diferente
#
# > maior
#
# < menor
#
# >= maior ou ugual
#
# <= menor ou igal
#
# # Operadores logicos
#
# and 'e'
#
# or 'ou'
#
# not 'nao'

# %%
 #calculadora simples

 # Entrada dois valores
 # processamento calcular usando operadores aritimedicos
 #Saida mostrar o resultado

 # Entrada

 numero1 = int (input("digite o primeiro numero: "))
 numero2 = int (input("digite o segundo numero"))

 # processamento

 soma = numero1 + numero2
 subtracao = numero1 - numero2
 multiplicacao = numero1 * numero2
 divisao = numero1 / numero2
 div_inteira =numero1 // numero2
resto = numero1 % mumero2
potencia = numero1 ** numero2

#Saida

print (f"o resultado da soma de dois numeros e igual: {soma}")
print (f"o resultado da subtracao de dois numeros e igual: {subtracao}")
print (f"o resultado da multiplicacao de dois numeros e igual: {multiplicacao}")
print (f"o resultado da divisao de dois numeros e igual: {divisao}")
print (f"o resultado da div_inteita de dois numeros e igual: {div_inteira}")
print (f"o resultado da resto de dois numeros e igual: {resto}")
print (f"o resultado da potencia de dois numeros e igual: {potencia}")
# Out:
# digite o primeiro numero: 14
# digite o segundo numero13
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_334/2186481548.py in <cell line: 0>()
#      17 divisao = numero1 / numero2
#      18 div_inteira =numero1 // numero2
# ---> 19 resto = numero1 % mumero2
#      20 potencia = numero1 ** numero2
#      21
#
# NameError: name 'mumero2' is not defined
