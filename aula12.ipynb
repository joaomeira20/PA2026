# %% [markdown]
# <a href="https://colab.research.google.com/github/joaomeira20/PA2026/blob/main/aula12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1#
nome = str(input("Qual seu nome"))
idade = int(input("Quantos anos voce tem?"))
cidade = str(input("qual sua cidade?"))

print(f"seu nome e {nome}, mora em {cidade} e tem {idade} anos")
# Out:
# Qual seu nomejoao
# Quantos anos voce tem?67
# qual sua cidade?ribeirao
# seu nome e joao, mora em ribeirao e tem 67 anos

# %%
2#
#entrada
numero = int(input("Escreva um numero"))
numero2 = numero + 1
numero3 = numero - 1
#processamento
print(f"seu numero escolhido e {numero}")
print(f"o numero superior e {numero2}")
print(f"o numero inferior e {numero3}")
# Out:
# Escreva um numero67
# seu numero escolhido e 67
# o numero superior e 68
# o numero inferior e 66

# %%
3#
#entrada

print("|--------- CALCULADORA----------|")
print("|                               |")
print("|-------------MENU--------------|")
print("|                               |")
print("|Opção = 1 - Soma               |")
print("|OPção = 2 - Subtração          |")
print("|Opção = 3 - Multiplicação      |")
print("|Opção = 4 - Divisão            |")
print("-------------------------------|")

#Entrada
numero = float (input("Digite um numero: "))
numero1 = float (input("Digite o segundo Numero: "))
opçao = int (input("Escolha a opção desejada: "))
#Processamento

if opçao == 1:
 print (f"A soma de {numero} mais {numero1} e igual a {numero + numero1}")

elif opçao == 2:
    print (f"a subtracao de {numero} e {numero1} e igual a {numero - numero1}")


elif opçao == 3:
  print (f"a multiplicaçao de {numero} e {numero1} e igual a {numero * numero1}")

elif opçao == 4:
 print (f" a divisao de {numero} e {numero1} e igual a {numero / numero1}")

else:
    print ("Opcao invalida")
# Out:
# |--------- CALCULADORA----------|
# |                               |
# |-------------MENU--------------|
# |                               |
# |Opção = 1 - Soma               |
# |OPção = 2 - Subtração          |
# |Opção = 3 - Multiplicação      |
# |Opção = 4 - Divisão            |
# -------------------------------|
# Digite um numero: 10
# Digite o segundo Numero: 10
# Escolha a opção desejada: 1
# A soma de 10.0 mais 10.0 e igual a 20.0

# %%
4#
#entrada
nome = str(input("Digite seu nome: "))

b1 = float(input("digite a primeira nota do aluno: "))
while b1 < 0 or b1 > 10:
  print ("nota invalida, digite uma nota de 0 a 10:")
  b1 = float(input("digite a primeira nota do aluno: "))

b2 = float(input("digite a segunda nota do aluno: "))
while b2 < 0 or b2 > 10:
  print ("nota invalida, digite uma nota de 0 a 10:")
  b2 = float(input("digite a segunda nota do aluno: "))

b3 = float(input("digite a terceira nota do aluno: "))
while b3 < 0 or b3 > 10:
  print ("nota invalida, digite uma nota de 0 a 10:")
  b3 = float(input("digite a terceira nota do aluno: "))

b4 = float(input("digite a quarta nota do aluno: "))
while b4 < 0 or b4 > 10:
  print ("nota invalida, digite uma nota de 0 a 10:")
  b4 = float(input("digite a quarta nota do aluno: "))


#processamento
nota = (b1 + b2 + b3 + b4) / 4

#saida
if nota < 5:
  print (f"-o aluno {nome} foi reprovado-")

elif nota <= 5 > 7:
  print (f"-o aluno {nome} esta de recuperação-")

else :
  print (f"-o aluno {nome} foi aprovado-")
# Out:
# Digite seu nome: joao
# digite a primeira nota do aluno: 10
# digite a segunda nota do aluno: 10
# digite a terceira nota do aluno: 10
# digite a quarta nota do aluno: 10
# -o aluno joao foi aprovado-

# %%
5#
valor = float(input("Digite a temperatura."))

farenhait = (valor * 1.8) + 32

print(f"o valor em  fahrenheit {farenhait}")
# Out:
# Digite a temperatura.19
# o valor em  fahrenheit 66.2

# %%
6#
base = float(input("Digite o valor da base"))
altura = float(input("Digite o valor da altura"))
area = base * altura

print(f"o valor da area do retangulo e {area}");
# Out:
# Digite o valor da base335
# Digite o valor da altura2
# o valor da area do retangulo e 670.0

# %%
7#
#Entrada
numero = int(input("Digite um numero: "))

#processamento / saida

if numero % 2 == 0:

  print (f"o numero {numero} é par.")


else:
  print (f"o numero {numero} é inpar")
# Out:
# Digite um numero: 67
# o numero 67 é inpar

# %%
8#
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
n3 = float(input("Digite o terceiro número: "))

if n1 > n2 and n1 > n3:
    maior = n1
elif n2 > n1 and n2 > n3:
    maior = n2
else:
    maior = n3

print("O maior número é:", maior)
# Out:
# Digite o primeiro número: 10
# Digite o segundo número: 42
# Digite o terceiro número: 67
# O maior número é: 67.0

# %%
9#
numero = int(input("Digite um numero"))

for i in range(11):
  print(f"{numero} x {i} = {numero * i}")
# Out:
# Digite um numero67
# 67 x 0 = 0
# 67 x 1 = 67
# 67 x 2 = 134
# 67 x 3 = 201
# 67 x 4 = 268
# 67 x 5 = 335
# 67 x 6 = 402
# 67 x 7 = 469
# 67 x 8 = 536
# 67 x 9 = 603
# 67 x 10 = 670

# %%
10#
numero1 = int (input("digite um numero: "))
numero2 = int (input("digite um numero: "))

soma = numero1 + numero2

print (f"A soma é {soma}")
# Out:
# digite um numero: 34
# digite um numero: 33
# A soma é 67
