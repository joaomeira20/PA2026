# %% [markdown]
# <a href="https://colab.research.google.com/github/joaomeira20/PA2026/blob/main/aula6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estrutura de decisões (if, elif e else)
# # Escrever um programa que compara 02 numéros
#
# #Entradas
# a = int (input("Digte um numero inteiro: "))
# b = int (input("Digite um numero inteiro: "))
#
# #Processamento / Saida
#
#  if a == b:
#    print (f"{a} E igual a {b}")
#
#  else:
#    print (f"{a} E diferente de {b}")
#
# ```
# # Isto está formatado como código
# ```

# %%
# escrever um programa que verifica se o numero digitado e par ou impar

#Entrada

numero = int(input("Digite um numero:"))

#processamento / saida

if numero % 2 == 0:

  print (f"o numero {numero} é par.")


else:
  print (f"o numero{numero} é inpar")
# Out:
# Digite um numero:4
# o numero 4 é par.

# %%
#Entrada

idade = int (input("Digite sua idade: "))

# Processamento / Saida

if % idade < 18:
 print (f" Vc tem {idade}, vc e um adulto")

else
 print (f"Vc tem {idade}, vc e um adolescente")
# Out:
#   File "/tmp/ipykernel_6959/1717114067.py", line 7
#     if % idade < 18:
#        ^
# SyntaxError: invalid syntax

# %%
# entrada
nome = str (input("digite seu mome: "))
idade = int (input("digiite sua idade: "))

#Processamento

if idade < 12 :

  print (f {nome}, voce e uma criança")

  elif idade < 18:
     print (f {nome}, voce e um adolescente")

  else:

    print ("Adulto")
# Out:
#   File "/tmp/ipykernel_6959/1487310372.py", line 11
#     elif idade < 18:
#     ^
# SyntaxError: invalid syntax

# %%
# escrever um programa de uam calculadora simples. o usuario ira digitar 02 numeros e escolhera uma operacao aritmedica

#entrada

print ("|--------- CALCULADORA----------|")
print ("|                               |")
print("|-------------MENU--------------|")
print("|                               |")
print("|Opção = 1 - Soma               |")
print("|OPção = 2 - Subtração          |")
print("|Opção = 3 - Multiplicação      |")
print("|Opção = 4 - Divisão            |")
print ("-------------------------------|")

#Entrada
numero = float (input("Digite um numero: "))
opçao = int (input("Escolha a opção desejada: "))
numero1 = float (input("Digite um Numero"))

#Processamento

if opçao == 1:
 print (f"A soma de {numero} mais {numero1} e igual a {numero + numer1}")

elif opçao == 2:
    print (f"a subtracao de {numero} e {numero1} e igual a {numero - numero1}")


elif opçao == 3:
  print (f"a multiplicaçao de {numero} e {numero1} e igual a {numero * numero1}")

elif opçao == 4:
 print (f" a divisao de {numero} e {numero1} e igual a {numero / numero1}")

else:
    print ("Opcao invalida")
# Out:
# |--------- CALCULADORA----------|
# |                               |
# |-------------MENU--------------|
# |                               |
# |Opção = 1 - Soma               |
# |OPção = 2 - Subtração          |
# |Opção = 3 - Multiplicação      |
# |Opção = 4 - Divisão            |
# -------------------------------|
# Digite um numero: 1
# Escolha a opção desejada: 3
# Digite um Numero8
# a multiplicaçao de 1.0 e 8.0 e igual a 8.0
