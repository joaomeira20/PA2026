# %% [markdown]
# <a href="https://colab.research.google.com/github/joaomeira20/PA2026/blob/main/atvPA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Entrada
numero = int(input("Digite um numero: "))

#processamento / saida

if numero % 2 == 0:

  print (f"o numero {numero} é par.")


else:
  print (f"o numero {numero} é inpar")
# Out:
# Digite um numero: 6
# o numero 6 é par.

# %%
#Entrada
numero1 = int(input("Digite o primeiro numero: "))
numero2 = int(input("Digite o segundo numero: "))

#Processamento e saida
if numero1 < numero2:
  print (f"o numero {numero1} e maior que o numero {numero2}.")

elif numero2 == numero1:
  print (f"os numeros {numero1} e {numero2} sao iguais.")

else:
  print (f'o numero {numero1} e menor que o numero {numero2}. ')
# Out:
# Digite o primeiro numero: 4
# Digite o segundo numero: 7
# o numero 4 e maior que o numero 7.

# %%
#entrada
nome = str(input("Digite seu nome: "))

b1 = float(input("digite a primeira nota do aluno: "))
while b1 < 0 or b1 > 10:
  print ("nota invalida, digite uma nota de 0 a 10:")
  b1 = float(input("digite a primeira nota do aluno: "))

b2 = float(input("digite a segunda nota do aluno: "))
while b2 < 0 or b2 > 10:
  print ("nota invalida, digite uma nota de 0 a 10:")
  b2 = float(input("digite a segunda nota do aluno: "))

b3 = float(input("digite a terceira nota do aluno: "))
while b3 < 0 or b3 > 10:
  print ("nota invalida, digite uma nota de 0 a 10:")
  b3 = float(input("digite a terceira nota do aluno: "))

b4 = float(input("digite a quarta nota do aluno: "))
while b4 < 0 or b4 > 10:
  print ("nota invalida, digite uma nota de 0 a 10:")
  b4 = float(input("digite a quarta nota do aluno: "))


#processamento
nota = (b1 + b2 + b3 + b4) / 4

#saida
if nota < 5:
  print (f"-o aluno {nome} foi reprovado-")

elif nota <= 5 > 7:
  print (f"-o aluno {nome} esta de recuperação-")

else :
  print (f"-o aluno {nome} foi aprovado-")
# Out:
# Digite seu nome: joao
# digite a primeira nota do aluno: 3
# digite a segunda nota do aluno: 10
# digite a terceira nota do aluno: 10
# digite a quarta nota do aluno: 10
# -o aluno joao foi aprovado-

# %%
# entrada
nome = str (input("digite seu nome: "))
idade = int (input("digiite sua idade: "))

#Processamento

if idade <= 12:
  print (f" {nome}, voce e uma criança")

elif idade  <= 17:
  print (f" {nome}, voce e um adolescente")

elif idade <= 59:
  print (f"voce e um adulto")

else:
  print ("voce e um idoso")
# Out:
# digite seu nome: joao
# digiite sua idade: 14
#  joao, voce e um adolescente

# %%
#Entrada
senha = 12345
entrada = int(input("digite sua senha: "))

#Processamento e saida

if entrada == senha:
  print(f"a senha esta correta")

else:
  print(f"a senha esta incorreta")
# Out:
# digite sua senha: 35789
# a senha esta incorreta

# %%
#Entrada
numero = int(input("digite o numero: "))

#processamento
if numero < 0:
 print(f"o numero {numero} e negativo")

elif numero == 0:
  print(f"o numero {numero} e igual a zero")

else:
  print(f"o numero {numero} e positivo")
# Out:
# digite o numero: 0
# o numero 0 e igual a zero

# %%
#entrada

print ("|--------- CALCULADORA----------|")
print ("|                               |")
print("|-------------MENU--------------|")
print("|                               |")
print("|Opção = 1 - Soma               |")
print("|OPção = 2 - Subtração          |")
print("|Opção = 3 - Multiplicação      |")
print("|Opção = 4 - Divisão            |")
print ("-------------------------------|")

#Entrada
numero = float (input("Digite um numero: "))
numero1 = float (input("Digite o segundo Numero: "))
opçao = int (input("Escolha a opção desejada: "))
#Processamento

if opçao == 1:
 print (f"A soma de {numero} mais {numero1} e igual a {numero + numer1}")

elif opçao == 2:
    print (f"a subtracao de {numero} e {numero1} e igual a {numero - numero1}")


elif opçao == 3:
  print (f"a multiplicaçao de {numero} e {numero1} e igual a {numero * numero1}")

elif opçao == 4:
 print (f" a divisao de {numero} e {numero1} e igual a {numero / numero1}")

else:
    print ("Opcao invalida")
# Out:
# |--------- CALCULADORA----------|
# |                               |
# |-------------MENU--------------|
# |                               |
# |Opção = 1 - Soma               |
# |OPção = 2 - Subtração          |
# |Opção = 3 - Multiplicação      |
# |Opção = 4 - Divisão            |
# -------------------------------|
# Digite um numero: 14
# Digite o segundo Numero: 27
# Escolha a opção desejada: 3
# a multiplicaçao de 14.0 e 27.0 e igual a 378.0

# %%
#Entrada
dia = int(input("digite o numero de 1 a 7: "))

#processamento e saida
if dia == 1:
  print(f"o dia {dia} e domingo.")

elif dia == 2:
  print(f"o dia {dia} e segunda.")

elif dia == 3:
  print(f"o dia {dia} e terça.")

elif dia == 4:
  print(f"o dia {dia} e quarta.")

elif dia == 5:
  print(f"o dia {dia} e quinta.")

elif dia == 6:
  print(f"o dia {dia} e sexta.")

else:
  print(f"o dia {dia} e sabado.")
# Out:
# digite o numero de 1 a 7: 7
# o dia 7 e sabado.

# %%
#Entrada
ano = int(input("digite o ano: "))

#processamento e saida

if ano % 4 == 0:
  print(f"o ano {ano} e bixesto.")

else:
  print(f"o ano {ano} não e bixesto.")
# Out:
# digite o ano: 2028
# o ano 2028 e bixesto.

# %%
#Entrada
compra = float(input(f"digite o valor total da compra: "))
print (f"valor da compra: R$: {compra}")

#Processamento e Saida
if (compra >= 100):
    des = compra * 0.10
    total = compra - des
    print(f"O valor total da sua compra com 10% de desconto é de: {total}")

elif (compra > 50) and ( compra <= 99):
    des2 = compra * 0.05
    total = compra - des2
    print(f"O valor total da sua compra com 20% de desconto é de: {total}")

else:
    print(f"O valor total da sua compra sem desconto é de: {compra}")
# Out:
# digite o valor total da compra: 188
# valor da compra: R$: 188.0
# O valor total da sua compra com 10% de desconto é de: 169.2
