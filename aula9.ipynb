# %% [markdown]
# <a href="https://colab.research.google.com/github/joaomeira20/PA2026/blob/main/aula9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loops  -  Laços e oterações

for i in range (5):
  print (f"ola mundo!")
# Out:
# ola mundo!
# ola mundo!
# ola mundo!
# ola mundo!
# ola mundo!

# %%
 # Escrever um programa que recebe um numero e retorma somenente os numeros pares

 numero = int(input("digite um numero: "))

for i in range (numero + 1):
  if i %  2 == 0:
   print (i)
# Out:
# digite um numero: 8
# 0
# 2
# 4
# 6
# 8

# %%
#Escrever um programa que recebe um numero e imprime uma contagem regressiva

numero = int(input("Digite um numero: "))

for i in range (numero + 1):
  print (numero - i)
# Out:
# Digite um numero: 9
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
palavra = str(input("digite ua palavra: "))
palindromo = ""

for i in (palavra):
  palindromo = i + palindromo

print(palindromo)
# Out:
# digite ua palavra: pyton
# notyp

# %%
numero =int(input("Digite o numero de 1 a 10 para mostar sua tabuada: "))
if numero < 1 or numero >= 11:
  print("Numero invalido escreva novamente um numero de 1 ate 10")
  numero =int(input("Digite o numero para mostar sua tabuada: "))
  if numero < 1 or numero >= 11:
    print("Numero invalido escreva novamente um numero de 1 ate 10")
    numero =int(input("Digite o numero para mostar sua tabuada: "))


for i in range (1, 11 ):
  print (f"{numero} x {i} =  {numero * i}")
